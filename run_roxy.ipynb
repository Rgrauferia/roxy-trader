# %% [markdown]
# # 🚀 Ejecutar Roxy Trader desde Colab

# %%
# ✅ Clonar el repositorio desde GitHub
# !git clone https://github.com/Rgrauferia/roxy-trader.git
# %cd roxy-trader

# %%
# ✅ Instalar dependencias necesarias
# !pip install -r requirements.txt

# %%
# ✅ Ejecutar script principal
# !python roxy_trader.py
